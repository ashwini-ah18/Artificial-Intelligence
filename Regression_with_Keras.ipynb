# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwini-ah18/Artificial-Intelligence/blob/main/Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression with Keras
# Project Objective: Build a model that predicts the power energy generated by a powerplant by considering the various sensor readings.
# Change the runtime type to T4 GPU

# %%
import pandas as pd
path = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlant.csv"
df = pd.read_csv(path)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.shape
# Out:
# (9568, 5)

# %%
## Check for duplicated information
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
# drop duplicates to handle duplicated information
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %% [markdown]
# Separate X and Y features
# X : AT(Atmospheric temperature),V (vaccum), AP : Atmospheric pressure, RH: Relative Humidity
#
# Y : PE (Power Energy)

# %%
X = df.drop(columns='PE')
Y = df[['PE']]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,train_size=0.80,random_state=21)

# %% [markdown]
# ## Data cleaning and preprocessing
# ## perform data cleaning as well as scaling of numerical data

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

num_pipe = make_pipeline(SimpleImputer(strategy="mean"), StandardScaler()).set_output(transform="pandas")

num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
num_pipe.fit(xtrain)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
xtrain_pre = num_pipe.transform(xtrain)
xtest_pre = num_pipe.transform(xtest)

# %%
xtrain_pre.head()
# Out:
#             AT         V        AP        RH
# 4531 -1.689756 -1.063410  1.555170  1.203072
# 6736  0.305120  0.521433  0.776416  0.634907
# 8019 -1.576686 -1.024717 -0.801408  1.677905
# 5136 -0.297919 -0.263486 -0.178404  0.715976
# 857  -1.292665 -1.155010  1.296150  0.049030

# %% [markdown]
# ## Model Building: Artificial Neural Network

# %%
xtrain.shape
# Out:
# (7621, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# Intialize the model
model = Sequential()

# Add the Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Hidden layer
model.add(Dense(units=8,activation='relu'))

# Add the output layer
model.add(Dense(units=1,activation='linear'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49 (196.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae'])

# %%
hist = model.fit(xtrain,ytrain,validation_split=0.2,epochs=50)
# Out:
# Epoch 1/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 396004.5625 - mae: 608.2870 - val_loss: 120883.3438 - val_mae: 346.7359
# Epoch 2/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37844.8828 - mae: 172.5899 - val_loss: 3745.4417 - val_mae: 54.6083
# Epoch 3/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1310.1361 - mae: 29.3662 - val_loss: 793.2276 - val_mae: 24.8587
# Epoch 4/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 781.2273 - mae: 24.6507 - val_loss: 769.2232 - val_mae: 24.6589
# Epoch 5/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 765.5935 - mae: 24.4344 - val_loss: 751.1896 - val_mae: 24.4146
# Epoch 6/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 748.6180 - mae: 24.1569 - val_loss: 732.7631 - val_mae: 24.1251
# Epoch 7/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 729.7308 - mae: 23.8670 - val_loss: 714.1105 - val_mae: 23.7790
# Epoch 8/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 708.3923 - mae: 23.5071 - val_loss: 692.4272 - val_mae: 23.4030
# Epoch 9/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 685.2814 - mae: 23.1041 - val_loss: 667.6043 - val_mae: 22.9990
# Epoch 10/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 660.2816 - mae: 22.6753 - val_loss: 643.6215 - val_mae: 22.5364
# Epoch 11/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 633.4949 - mae: 22.2054 - val_loss: 613.9744 - val_mae: 22.0607
# Epoch 12/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 605.1968 - mae: 21.7044 - val_loss: 585.1535 - val_mae: 21.5283
# Epoch 13/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 575.4075 - mae: 21.1504 - val_loss: 555.8607 - val_mae: 20.9429
# Epoch 14/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 544.3247 - mae: 20.5576 - val_loss: 526.9454 - val_mae: 20.3131
# Epoch 15/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 511.6611 - mae: 19.9235 - val_loss: 492.4078 - val_mae: 19.6740
# Epoch 16/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 478.4957 - mae: 19.2431 - val_loss: 464.1307 - val_mae: 18.9518
# Epoch 17/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 444.1442 - mae: 18.4968 - val_loss: 423.8754 - val_mae: 18.3251
# Epoch 18/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 411.4159 - mae: 17.8312 - val_loss: 394.9379 - val_mae: 17.4542
# Epoch 19/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 377.0003 - mae: 17.0040 - val_loss: 356.7116 - val_mae: 16.7078
# Epoch 20/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 343.6751 - mae: 16.2249 - val_loss: 323.5640 - val_mae: 15.8707
# Epoch 21/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 310.0792 - mae: 15.3703 - val_loss: 293.0562 - val_mae: 14.9663
# Epoch 22/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 277.6334 - mae: 14.4957 - val_loss: 259.9360 - val_mae: 14.1300
# Epoch 23/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 247.2762 - mae: 13.6332 - val_loss: 231.6012 - val_mae: 13.1862
# Epoch 24/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 217.8690 - mae: 12.7306 - val_loss: 202.7712 - val_mae: 12.2985
# Epoch 25/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 190.4552 - mae: 11.8320 - val_loss: 177.3412 - val_mae: 11.3817
# Epoch 26/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 165.6010 - mae: 10.9442 - val_loss: 152.9527 - val_mae: 10.5190
# Epoch 27/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142.4628 - mae: 10.0650 - val_loss: 132.9405 - val_mae: 9.6335
# Epoch 28/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 122.2530 - mae: 9.2476 - val_loss: 114.0988 - val_mae: 8.8361
# Epoch 29/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.7529 - mae: 8.4755 - val_loss: 99.0624 - val_mae: 8.1091
# Epoch 30/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 89.7134 - mae: 7.7668 - val_loss: 83.2276 - val_mae: 7.4877
# Epoch 31/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 76.8236 - mae: 7.1480 - val_loss: 71.8857 - val_mae: 6.9876
# Epoch 32/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.4854 - mae: 6.6244 - val_loss: 62.5109 - val_mae: 6.4274
# Epoch 33/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58.1171 - mae: 6.1664 - val_loss: 55.8318 - val_mae: 5.9795
# Epoch 34/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 51.8083 - mae: 5.8169 - val_loss: 49.4845 - val_mae: 5.6357
# Epoch 35/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46.1009 - mae: 5.4709 - val_loss: 44.6390 - val_mae: 5.4052
# Epoch 36/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42.0205 - mae: 5.2204 - val_loss: 40.9887 - val_mae: 5.1294
# Epoch 37/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38.7320 - mae: 5.0084 - val_loss: 38.1067 - val_mae: 4.9502
# Epoch 38/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 36.2418 - mae: 4.8397 - val_loss: 35.8656 - val_mae: 4.7777
# Epoch 39/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34.1662 - mae: 4.6852 - val_loss: 34.1438 - val_mae: 4.6795
# Epoch 40/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 32.5867 - mae: 4.5643 - val_loss: 32.5927 - val_mae: 4.5424
# Epoch 41/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.4016 - mae: 4.4743 - val_loss: 32.5978 - val_mae: 4.5931
# Epoch 42/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.2971 - mae: 4.3881 - val_loss: 30.9056 - val_mae: 4.3932
# Epoch 43/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.3805 - mae: 4.3208 - val_loss: 29.6846 - val_mae: 4.3272
# Epoch 44/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.7290 - mae: 4.2634 - val_loss: 29.1433 - val_mae: 4.2788
# Epoch 45/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.1406 - mae: 4.2214 - val_loss: 28.6337 - val_mae: 4.2416
# Epoch 46/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28.0060 - mae: 4.2202 - val_loss: 28.4090 - val_mae: 4.2176
# Epoch 47/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.5431 - mae: 4.1689 - val_loss: 28.0102 - val_mae: 4.1967
# Epoch 48/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.8788 - mae: 4.1929 - val_loss: 28.6281 - val_mae: 4.2266
# Epoch 49/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 27.3818 - mae: 4.1527 - val_loss: 28.9928 - val_mae: 4.2482
# Epoch 50/50
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27.2326 - mae: 4.1474 - val_loss: 31.6462 - val_mae: 4.4196

# %% [markdown]
# ##Model Evaluation
#
# ## Learning Curve : to understand the behaviour of loss with increased number of epochs

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'],label = "Training loss")
plt.plot(hist.history['val_loss'],label = "Validation loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 30.9956 - mae: 4.3647
# [30.995561599731445, 4.364741325378418]

# %%
model.evaluate(xtest,ytest)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.5404 - mae: 4.3500
# [30.540401458740234, 4.3499674797058105]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
ypreds = model.predict(xtest)

# MSE,RMSE,MAE,R2 score
mse = mean_squared_error(ytest,ypreds)
rmse = mse**(1/2)
mae = mean_absolute_error(ytest,ypreds)
r2 = r2_score(ytest,ypreds)

print(f"MSE: {mse:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"MAE:{mae:.2f}")
print(f"R2 score:{r2*100:.2f}%")
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE: 30.54
# RMSE : 5.53
# MAE:4.35
# R2 score:89.51%

# %% [markdown]
# ##R2 score of 90.67% is a very good score. We can definitely consider this model for deployment

# %%
model.save("PowerEnergymodel.keras")

# %%
import joblib
joblib.dump(num_pipe,"Pipeline_data_cleaning_scaling.joblib")
# Out:
# ['Pipeline_data_cleaning_scaling.joblib']

# %%
from keras.models import load_model

model_loaded = load_model(r"/content/PowerEnergymodel.keras")
model_loaded.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 149 (600.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 100 (404.00 B)

# %%
pipeline = joblib.load(r"/content/Pipeline_data_cleaning_scaling.joblib")
pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# Example deployment scenario

# %%
path2 = r"https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlantTest.csv"
sample_data = pd.read_csv(path2)
sample_data
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %% [markdown]
# **we handle data cleaning as well as scaling on the new data**

# %%
sample_cleaned = pipeline.transform(sample_data)
sample_cleaned
# Out:
#          AT         V        AP        RH
# 0  0.718363 -0.216107 -2.220095 -1.109781
# 1  1.660612 -1.045248  6.413920  0.457100
# 2  1.122184  0.000000 -0.510221  0.000000

# %% [markdown]
# ### Model predictions

# %%
preds = model_loaded.predict(sample_cleaned)
preds = preds.round(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step

# %%
preds
# Out:
# array([[-0.95],
#        [ 2.09],
#        [-0.33]], dtype=float32)

# %% [markdown]
# ## Combine the predictions to the sample data and share it with the client

# %%
sample_data
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
sample_data["PowerEnergy_Predicted"] = preds
sample_data
# Out:
#    AT     V      AP    RH  PowerEnergy_Predicted
# 0  25  51.5  1000.1  57.0                  -0.95
# 1  32  41.0  1051.1  80.0                   2.09
# 2  28   NaN  1010.2   NaN                  -0.33

# %%
sample_data.to_csv("PE Predicted.csv",index=False)
